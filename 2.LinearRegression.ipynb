# %% [markdown]
# # Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.nn import Module, Linear, MSELoss
from torch.optim import SGD
from torch.utils.data import Dataset, DataLoader

# %%
class plot_error_surfaces(object):
    def __init__(self, w_range, b_range, X, Y, n_samples = 30, go = True):
        W = np.linspace(-w_range, w_range, n_samples)
        B = np.linspace(-b_range, b_range, n_samples)
        w, b = np.meshgrid(W, B)    
        Z = np.zeros((30,30))
        count1 = 0
        self.y = Y.numpy()
        self.x = X.numpy()
        for w1, b1 in zip(w, b):
            count2 = 0
            for w2, b2 in zip(w1, b1):
                Z[count1, count2] = np.mean((self.y - w2 * self.x + b2) ** 2)
                count2 += 1
            count1 += 1
        self.Z = Z
        self.w = w
        self.b = b
        self.W = []
        self.B = []
        self.LOSS = []
        self.n = 0
        if go == True:
            plt.figure()
            plt.figure(figsize = (7.5, 5))
            plt.axes(projection='3d').plot_surface(self.w, self.b, self.Z, rstride = 1, cstride = 1,cmap = 'viridis', edgecolor = 'none')
            plt.title('Cost/Total Loss Surface')
            plt.xlabel('w')
            plt.ylabel('b')
            plt.show()
            plt.figure()
            plt.title('Cost/Total Loss Surface Contour')
            plt.xlabel('w')
            plt.ylabel('b')
            plt.contour(self.w, self.b, self.Z)
            plt.show()
 
    def set_para_loss(self, W, B, loss):
        self.n = self.n + 1
        self.W.append(W)
        self.B.append(B)
        self.LOSS.append(loss)
    
    def final_plot(self): 
        ax = plt.axes(projection = '3d')
        ax.plot_wireframe(self.w, self.b, self.Z)
        ax.scatter(self.W,self.B, self.LOSS, c = 'r', marker = 'x', s = 200, alpha = 1)
        plt.figure()
        plt.contour(self.w,self.b, self.Z)
        plt.scatter(self.W, self.B, c = 'r', marker = 'x')
        plt.xlabel('w')
        plt.ylabel('b')
        plt.show()
    
    def plot_ps(self):
        plt.subplot(121)
        plt.ylim
        plt.plot(self.x, self.y, 'ro', label="training points")
        plt.plot(self.x, self.W[-1] * self.x + self.B[-1], label = "estimated line")
        plt.xlabel('x')
        plt.ylabel('y')
        plt.ylim((-10, 15))
        plt.title('Data Space Iteration: ' + str(self.n))

        plt.subplot(122)
        plt.contour(self.w, self.b, self.Z)
        plt.scatter(self.W, self.B, c = 'r', marker = 'x')
        plt.title('Total Loss Surface Contour Iteration' + str(self.n))
        plt.xlabel('w')
        plt.ylabel('b')
        plt.show()

# %% [markdown]
# We know that a simple linear regression has the following equation:
# $$\hat{y} = w\times x + b$$
# where $w$ is the weight of a feature and $b$ is the bias. Let's say that the value of $w$ is $2$, and the value of $b$. Then the prediction for a new value $x$ will be
# $$\hat{y} = 2\times x - 1$$
# Now, we will calculate the same equation using `Tensor`. First we will initialize the weight and bias.

# %%
w = torch.tensor(2.0, requires_grad = True)
b = torch.tensor(-1.0, requires_grad = True)

# %% [markdown]
# Then we will define a function named `forward` to compute $\hat{y}$.

# %%
def forward(x):
    yhat = w * x + b
    return yhat

# %% [markdown]
# Then we will predict when $x = 1$.

# %%
x = torch.tensor([[1.0]])
yhat = forward(x)
print("The prediction: ", yhat)
# Out:
# The prediction:  tensor([[1.]], grad_fn=<AddBackward0>)

# %% [markdown]
# Now we will predict for multiple inputs.

# %%
x = torch.tensor([[1.0], [2.0]])
print("The shape of x: ", x.shape)
# Out:
# The shape of x:  torch.Size([2, 1])

# %%
yhat = forward(x)
print("The prediction: ", yhat)
# Out:
# The prediction:  tensor([[1.],
#         [3.]], grad_fn=<AddBackward0>)

# %% [markdown]
# We can achieve the same thing that we have done so far using the `nn.Linear` class of PyTorch.

# %%
lr = Linear(in_features=1, out_features=1, bias=True)
print("Parameters w and b: ", list(lr.parameters()))
# Out:
# Parameters w and b:  [Parameter containing:
# tensor([[-0.1572]], requires_grad=True), Parameter containing:
# tensor([0.7545], requires_grad=True)]

# %% [markdown]
# A method  <code>state_dict()</code> Returns a Python dictionary object corresponding to each parameter tensor.

# %%
print("Python dictionary: ",lr.state_dict())
print("keys: ",lr.state_dict().keys())
print("values: ",lr.state_dict().values())
# Out:
# Python dictionary:  OrderedDict([('weight', tensor([[-0.1572]])), ('bias', tensor([0.7545]))])
# keys:  odict_keys(['weight', 'bias'])
# values:  odict_values([tensor([[-0.1572]]), tensor([0.7545])])

# %% [markdown]
# The keys correspond to the name of the attributes and the values correspond to the parameter value.

# %%
print("weight:",lr.weight)
print("bias:",lr.bias)
# Out:
# weight: Parameter containing:
# tensor([[-0.1572]], requires_grad=True)
# bias: Parameter containing:
# tensor([0.7545], requires_grad=True)

# %% [markdown]
# Now, we will make a signle prediction when $x = 1$.

# %%
x = torch.tensor([[1.0]])
yhat = lr(x)
print("The prediction: ", yhat)
# Out:
# The prediction:  tensor([[0.5973]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# We can also make predictions when we have multiple input values.

# %%
x = torch.tensor([[1.0], [2.0]])
yhat = lr(x)
print("The prediction: ", yhat)
# Out:
# The prediction:  tensor([[0.5973],
#         [0.4400]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Model
# We can make a custom module to implement the linear regression model.

# %%
class LinearRegression(Module):
    def __init__(self, input_size, output_size):
        super(LinearRegression, self).__init__()
        self.linear = Linear(input_size, output_size)
    
    def forward(self, x):
        out = self.linear(x)
        return out

# %%
lr = LinearRegression(1, 1)
print("The parameters: ", list(lr.parameters()))
print("Linear model: ", lr.linear)
# Out:
# The parameters:  [Parameter containing:
# tensor([[0.6954]], requires_grad=True), Parameter containing:
# tensor([-0.0844], requires_grad=True)]
# Linear model:  Linear(in_features=1, out_features=1, bias=True)

# %% [markdown]
# We will make prediction when we have only single input.

# %%
x = torch.tensor([[1.0]])
yhat = lr(x)
print("The prediction: ", yhat)
# Out:
# The prediction:  tensor([[0.6111]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# We will make predictions when we have multiple samples.

# %%
x = torch.tensor([[1.0], [2.0]])
yhat = lr(x)
print("The prediction: ", yhat)
# Out:
# The prediction:  tensor([[0.6111],
#         [1.3065]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# We can also list all the parameters of our module.

# %%
print("Python dictionary: ", lr.state_dict())
print("keys: ",lr.state_dict().keys())
print("values: ",lr.state_dict().values())
# Out:
# Python dictionary:  OrderedDict([('linear.weight', tensor([[0.6954]])), ('linear.bias', tensor([-0.0844]))])
# keys:  odict_keys(['linear.weight', 'linear.bias'])
# values:  odict_values([tensor([[0.6954]]), tensor([-0.0844])])

# %% [markdown]
# # Training

# %% [markdown]
# First we will create some custom dataset. Here, we have generate values from -3 to 3 that create a line with a slope of $-3$. This is the line we will estimate.

# %%
X = torch.arange(-3, 3, 0.1).view(-1, 1)
f = -3 * X

# %%
plt.plot(X.numpy(), f.numpy(), label = 'f')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# Let us add some noise to the data in order to simulate the real data. Use <code>torch.randn(X.size())</code> to generate Gaussian noise that is the same size as <code>X</code> and has a standard deviation opf 0.1.

# %%
Y = f + 0.1 * torch.randn(X.size())

# %%
plt.plot(X.numpy(), Y.numpy(), 'rx', label = 'Y')
plt.plot(X.numpy(), f.numpy(), label = 'f')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# Next, we will create our model.

# %%
def forward(x):
    return w * x + b

# %% [markdown]
# And then we will define our cost function which is the mean squared error.

# %%
def criterion(yhat, y):
    return torch.mean((yhat - y) ** 2)

# %% [markdown]
# Then we will randomly initialize our weight and bias.

# %%
w = torch.tensor(-15.0, requires_grad = True)
b = torch.tensor(-10.0, requires_grad = True)

# %% [markdown]
# Then we will fix a value for our learning rate. We will keep a separte list to keep losses at each epoch.

# %%
lr = 0.1
LOSS = []
get_surface = plot_error_surfaces(15, 15, X, Y, 30)

# %% [markdown]
# Finally, we will train our model.

# %%
def train_model(iter):
    for epoch in range(iter):
        Yhat = forward(X)
        loss = criterion(Yhat, Y)
        LOSS.append(loss)
        
        get_surface.set_para_loss(w.data.tolist(), b.data.tolist(), loss.tolist())
        if epoch % 3 == 0:
            get_surface.plot_ps()
        
        loss.backward()
        w.data = w.data - lr * w.grad.data
        b.data = b.data - lr * b.grad.data
        
        w.grad.data.zero_()
        b.grad.data.zero_()

# %%
train_model(15)

# %% [markdown]
# # PyTorch Way
# Let's create a custom `Dataset` and a `DataLoader`.

# %%
class Data(Dataset):
    def __init__(self):
        self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
        self.f = 1 * self.x - 1
        self.y = self.f + 0.1 * torch.randn(self.x.size())
        self.len = self.x.shape[0]
        
    def __getitem__(self,index):    
        return self.x[index], self.y[index]
    
    def __len__(self):
        return self.len

# %% [markdown]
# Initialize the `Data`.

# %%
dataset = Data()

# %%
plt.plot(dataset.x.numpy(), dataset.y.numpy(), 'rx', label = 'y')
plt.plot(dataset.x.numpy(), dataset.f.numpy(), label = 'f')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %%
class LinearRegression(Module):
    def __init__(self, input_size, output_size):
        super(LinearRegression, self).__init__()
        self.linear = Linear(input_size, output_size)
        
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# We will use PyTorch build-in functions to create a criterion function; this calculates the total loss or cost.

# %%
criterion = MSELoss()

# %%
model = LinearRegression(1, 1)
optimizer = SGD(model.parameters(), lr = 0.01)

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-0.2096]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.8645], requires_grad=True)]

# %%
optimizer.state_dict()
# Out:
# {'state': {},
#  'param_groups': [{'lr': 0.01,
#    'momentum': 0,
#    'dampening': 0,
#    'weight_decay': 0,
#    'nesterov': False,
#    'maximize': False,
#    'params': [0, 1]}]}

# %% [markdown]
# Create a `DataLoader` instance.

# %%
trainloader = DataLoader(dataset = dataset, batch_size = 1)
get_surface = plot_error_surfaces(15, 13, dataset.x, dataset.y, 30, go = False)

# %%
def train_model(iter):
    for epoch in range(iter):
        for i, (x, y) in enumerate(trainloader):
            yhat = model(x)
            loss = criterion(yhat, y)   
            print('Epoch ', epoch, ' round ', i, ' : Loss ', loss)    
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

train_model(10)
# Out:
# Epoch  0  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  0  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  0  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  0  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  0  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  0  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  0  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  0  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  0  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  0  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  0  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  0  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  0  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  0  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  0  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  0  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  0  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  0  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  0  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  0  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  0  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  0  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  0  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  0  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  0  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  0  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  0  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  0  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  0  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  0  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  0  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  0  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  0  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  0  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  0  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  0  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  0  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  0  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  0  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  0  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  0  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  0  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  0  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  0  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  0  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  0  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  0  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  0  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  0  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  0  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  0  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  0  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  0  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  0  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  0  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  0  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  0  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  0  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  0  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  0  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch  1  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  1  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  1  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  1  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  1  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  1  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  1  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  1  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  1  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  1  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  1  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  1  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  1  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  1  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  1  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  1  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  1  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  1  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  1  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  1  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  1  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  1  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  1  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  1  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  1  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  1  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  1  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  1  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  1  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  1  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  1  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  1  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  1  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  1  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  1  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  1  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  1  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  1  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  1  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  1  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  1  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  1  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  1  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  1  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  1  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  1  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  1  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  1  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  1  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  1  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  1  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  1  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  1  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  1  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  1  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  1  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  1  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  1  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  1  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  1  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch  2  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  2  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  2  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  2  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  2  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  2  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  2  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  2  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  2  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  2  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  2  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  2  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  2  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  2  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  2  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  2  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  2  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  2  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  2  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  2  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  2  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  2  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  2  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  2  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  2  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  2  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  2  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  2  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  2  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  2  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  2  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  2  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  2  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  2  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  2  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  2  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  2  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  2  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  2  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  2  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  2  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  2  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  2  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  2  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  2  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  2  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  2  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  2  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  2  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  2  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  2  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  2  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  2  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  2  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  2  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  2  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  2  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  2  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  2  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  2  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch  3  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  3  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  3  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  3  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  3  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  3  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  3  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  3  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  3  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  3  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  3  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  3  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  3  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  3  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  3  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  3  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  3  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  3  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  3  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  3  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  3  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  3  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  3  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  3  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  3  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  3  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  3  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  3  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  3  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  3  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  3  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  3  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  3  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  3  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  3  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  3  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  3  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  3  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  3  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  3  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  3  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  3  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  3  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  3  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  3  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  3  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  3  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  3  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  3  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  3  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  3  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  3  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  3  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  3  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  3  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  3  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  3  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  3  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  3  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  3  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch  4  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  4  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  4  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  4  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  4  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  4  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  4  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  4  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  4  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  4  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  4  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  4  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  4  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  4  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  4  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  4  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  4  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  4  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  4  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  4  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  4  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  4  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  4  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  4  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  4  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  4  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  4  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  4  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  4  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  4  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  4  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  4  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  4  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  4  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  4  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  4  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  4  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  4  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  4  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  4  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  4  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  4  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  4  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  4  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  4  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  4  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  4  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  4  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  4  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  4  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  4  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  4  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  4  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  4  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  4  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  4  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  4  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  4  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  4  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  4  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch  5  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  5  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  5  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  5  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  5  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  5  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  5  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  5  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  5  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  5  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  5  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  5  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  5  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  5  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  5  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  5  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  5  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  5  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  5  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  5  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  5  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  5  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  5  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  5  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  5  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  5  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  5  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  5  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  5  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  5  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  5  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  5  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  5  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  5  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  5  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  5  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  5  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  5  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  5  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  5  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  5  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  5  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  5  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  5  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  5  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  5  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  5  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  5  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  5  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  5  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  5  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  5  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  5  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  5  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  5  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  5  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  5  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  5  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  5  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  5  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch  6  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  6  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  6  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  6  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  6  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  6  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  6  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  6  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  6  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  6  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  6  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  6  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  6  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  6  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  6  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  6  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  6  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  6  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  6  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  6  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  6  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  6  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  6  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  6  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  6  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  6  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  6  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  6  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  6  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  6  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  6  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  6  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  6  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  6  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  6  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  6  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  6  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  6  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  6  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  6  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  6  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  6  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  6  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  6  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  6  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  6  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  6  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  6  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  6  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  6  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  6  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  6  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  6  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  6  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  6  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  6  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  6  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  6  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  6  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  6  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch  7  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  7  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  7  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  7  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  7  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  7  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  7  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  7  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  7  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  7  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  7  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  7  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  7  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  7  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  7  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  7  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  7  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  7  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  7  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  7  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  7  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  7  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  7  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  7  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  7  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  7  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  7  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  7  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  7  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  7  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  7  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  7  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  7  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  7  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  7  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  7  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  7  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  7  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  7  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  7  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  7  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  7  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  7  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  7  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  7  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  7  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  7  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  7  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  7  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  7  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  7  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  7  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  7  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  7  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  7  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  7  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  7  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  7  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  7  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  7  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch  8  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  8  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  8  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  8  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  8  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  8  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  8  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  8  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  8  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  8  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  8  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  8  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  8  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  8  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  8  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  8  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  8  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  8  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  8  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  8  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  8  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  8  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  8  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  8  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  8  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  8  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  8  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  8  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  8  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  8  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  8  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  8  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  8  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  8  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  8  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  8  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  8  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  8  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  8  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  8  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  8  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  8  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  8  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  8  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  8  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  8  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  8  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  8  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  8  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  8  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  8  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  8  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  8  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  8  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  8  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  8  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  8  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  8  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  8  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  8  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch  9  round  0  : Loss  tensor(0.0003, grad_fn=<MseLossBackward0>)
# Epoch  9  round  1  : Loss  tensor(0.0161, grad_fn=<MseLossBackward0>)
# Epoch  9  round  2  : Loss  tensor(0.0110, grad_fn=<MseLossBackward0>)
# Epoch  9  round  3  : Loss  tensor(0.0153, grad_fn=<MseLossBackward0>)
# Epoch  9  round  4  : Loss  tensor(1.8354e-05, grad_fn=<MseLossBackward0>)
# Epoch  9  round  5  : Loss  tensor(0.0334, grad_fn=<MseLossBackward0>)
# Epoch  9  round  6  : Loss  tensor(0.0017, grad_fn=<MseLossBackward0>)
# Epoch  9  round  7  : Loss  tensor(0.0081, grad_fn=<MseLossBackward0>)
# Epoch  9  round  8  : Loss  tensor(0.0088, grad_fn=<MseLossBackward0>)
# Epoch  9  round  9  : Loss  tensor(0.0589, grad_fn=<MseLossBackward0>)
# Epoch  9  round  10  : Loss  tensor(0.0047, grad_fn=<MseLossBackward0>)
# Epoch  9  round  11  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  9  round  12  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  9  round  13  : Loss  tensor(0.0257, grad_fn=<MseLossBackward0>)
# Epoch  9  round  14  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  9  round  15  : Loss  tensor(0.0026, grad_fn=<MseLossBackward0>)
# Epoch  9  round  16  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  9  round  17  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  9  round  18  : Loss  tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch  9  round  19  : Loss  tensor(0.0158, grad_fn=<MseLossBackward0>)
# Epoch  9  round  20  : Loss  tensor(0.0002, grad_fn=<MseLossBackward0>)
# Epoch  9  round  21  : Loss  tensor(0.0197, grad_fn=<MseLossBackward0>)
# Epoch  9  round  22  : Loss  tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch  9  round  23  : Loss  tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch  9  round  24  : Loss  tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch  9  round  25  : Loss  tensor(0.0209, grad_fn=<MseLossBackward0>)
# Epoch  9  round  26  : Loss  tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch  9  round  27  : Loss  tensor(0.0154, grad_fn=<MseLossBackward0>)
# Epoch  9  round  28  : Loss  tensor(0.0179, grad_fn=<MseLossBackward0>)
# Epoch  9  round  29  : Loss  tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch  9  round  30  : Loss  tensor(0.0073, grad_fn=<MseLossBackward0>)
# Epoch  9  round  31  : Loss  tensor(0.0139, grad_fn=<MseLossBackward0>)
# Epoch  9  round  32  : Loss  tensor(0.0005, grad_fn=<MseLossBackward0>)
# Epoch  9  round  33  : Loss  tensor(0.0185, grad_fn=<MseLossBackward0>)
# Epoch  9  round  34  : Loss  tensor(0.0399, grad_fn=<MseLossBackward0>)
# Epoch  9  round  35  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  9  round  36  : Loss  tensor(0.0057, grad_fn=<MseLossBackward0>)
# Epoch  9  round  37  : Loss  tensor(0.0118, grad_fn=<MseLossBackward0>)
# Epoch  9  round  38  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  9  round  39  : Loss  tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch  9  round  40  : Loss  tensor(2.2464e-07, grad_fn=<MseLossBackward0>)
# Epoch  9  round  41  : Loss  tensor(7.9177e-05, grad_fn=<MseLossBackward0>)
# Epoch  9  round  42  : Loss  tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch  9  round  43  : Loss  tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch  9  round  44  : Loss  tensor(0.0029, grad_fn=<MseLossBackward0>)
# Epoch  9  round  45  : Loss  tensor(0.0045, grad_fn=<MseLossBackward0>)
# Epoch  9  round  46  : Loss  tensor(8.8610e-05, grad_fn=<MseLossBackward0>)
# Epoch  9  round  47  : Loss  tensor(0.0078, grad_fn=<MseLossBackward0>)
# Epoch  9  round  48  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  9  round  49  : Loss  tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch  9  round  50  : Loss  tensor(0.0160, grad_fn=<MseLossBackward0>)
# Epoch  9  round  51  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  9  round  52  : Loss  tensor(0.0513, grad_fn=<MseLossBackward0>)
# Epoch  9  round  53  : Loss  tensor(0.0037, grad_fn=<MseLossBackward0>)
# Epoch  9  round  54  : Loss  tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch  9  round  55  : Loss  tensor(0.0261, grad_fn=<MseLossBackward0>)
# Epoch  9  round  56  : Loss  tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch  9  round  57  : Loss  tensor(0.0151, grad_fn=<MseLossBackward0>)
# Epoch  9  round  58  : Loss  tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch  9  round  59  : Loss  tensor(0.0019, grad_fn=<MseLossBackward0>)
